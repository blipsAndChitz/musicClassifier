# %% [markdown]
# ## Music genre classifier
# - normalizovat data
# - dorobit vizualizacie pre features
# - feature engineering
# - spravit roznomernu distribuciu dat v datasete
# - doplnit tokenizovany text do features listu, tokenizacia mena kapely
# - skusit ine klasifikatory(random forest)
# - grid search
# - hrat sa s jednotlivymi triedami
# - dokumentacia
# - confusion_matrix pre vysledky

# %%
import pandas as pd
import numpy as np

import os
from os import path
from os import getcwd

from matplotlib import pyplot as plt
import seaborn as sb

import sklearn
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier, export_graphviz

import nltk
from nltk.corpus import stopwords

import io
from scipy import misc
import pydotplus
import graphviz

import warnings

#nltk.download()

os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# %%
data_filename = path.join(getcwd(), '..', 'msd_genre_dataset.txt')
print(data_filename)

pandas_data = pd.read_csv(data_filename, header=0).decode("utf8")
del pandas_data['track_id']
pandas_data['tokenized_title'] = pandas_data.apply(lambda row: nltk.word_tokenize(row['title']), axis=1)
# Out:
# C:\Users\jakub\Desktop\MichalKodiDodzaleny\..\msd_genre_dataset.txt

# %%
stop_words = stopwords.words('english')

#for i,row in pandas_data.iterrows():
#    print(row.tokenized_title)
#    row.tokenized_title = [word for word in row.tokenized_title if not word.lower() in stop_words and word.isalpha()]
#    print(row.tokenized_title)

def removeStopWors(words):
    out = [word for word in words if not word.lower() in stop_words and word.isalpha()]
    return out

pandas_data['tokenized_title'] = pandas_data.apply(lambda row: removeStopWors(row['tokenized_title']), axis=1)

pandas_data
# Out:
#                      %genre              artist_name  \
# 0      classic pop and rock         Blue Oyster Cult
# 1      classic pop and rock         Blue Oyster Cult
# 2      classic pop and rock         Blue Oyster Cult
# 3      classic pop and rock         Blue Oyster Cult
# 4      classic pop and rock         Blue Oyster Cult
# 5      classic pop and rock         Blue Oyster Cult
# 6      classic pop and rock         Blue Oyster Cult
# 7      classic pop and rock         Blue Oyster Cult
# 8      classic pop and rock         Blue Oyster Cult
# 9      classic pop and rock         Blue Oyster Cult
# 10     classic pop and rock         Blue Oyster Cult
# 11     classic pop and rock         Blue Oyster Cult
# 12     classic pop and rock         Blue Oyster Cult
# 13     classic pop and rock         Blue Oyster Cult
# 14     classic pop and rock         Blue Oyster Cult
# 15     classic pop and rock         Blue Oyster Cult
# 16     classic pop and rock         Blue Oyster Cult
# 17     classic pop and rock         Blue Oyster Cult
# 18     classic pop and rock         Blue Oyster Cult
# 19     classic pop and rock         Blue Oyster Cult
# 20     classic pop and rock         Blue Oyster Cult
# 21     classic pop and rock         Blue Oyster Cult
# 22     classic pop and rock         Blue Oyster Cult
# 23     classic pop and rock         Blue Oyster Cult
# 24     classic pop and rock         Blue Oyster Cult
# 25     classic pop and rock         Blue Oyster Cult
# 26     classic pop and rock         Blue Oyster Cult
# 27     classic pop and rock         Blue Oyster Cult
# 28     classic pop and rock         Blue Oyster Cult
# 29     classic pop and rock         Blue Oyster Cult
# ...                     ...                      ...
# 59570       soul and reggae                   Erikah
# 59571       soul and reggae              Erykah Badu
# 59577    362.441247    628.971359                       [Apple, Tree]
# 59578    391.171410    449.465490                                  []
# 59579    410.875814    517.714660                    [Next, Lifetime]
# 59580    322.992640    604.265959                                  []
# 59581    505.862105    767.590862                         [Bag, Lady]
# 59582    383.349800    312.589603                        [Hey, Sugah]
# 59583    572.860269    477.260112                         [Bag, Lady]
# 59584    436.919522    594.714710                              [Hump]
# 59585    435.912937    381.681691                                  []
# 59586    393.651343    396.008530                           [Twinkle]
# 59587    531.444158    481.791847                   [Master, Teacher]
# 59588    424.565553    268.325485                              [Cell]
# 59589    323.380721    459.931348                            [People]
# 59590    402.511335    335.370413                        [Feet, Tall]
# 59591    669.821921    347.390881               [Fall, Love, funeral]
# 59592    276.385797    344.769425                          [Umm, Hmm]
# 59593    486.911721    446.738452                      [Window, Seat]
# 59594    531.901731    407.200144                         [Back, Day]
# 59595    641.508417    395.121718                            [Danger]
# 59596    504.899788    350.913794                         [Hollywood]
# 59597    538.895856    313.775934                      [Think, Twice]
# 59598    598.054091    443.893807                             [Grind]
# 59599    531.850198    607.215961                              [Want]
#
# [59600 rows x 34 columns]

# %%
# list(pandas_data.columns.values)
genre_column = pandas_data['%genre']
print(genre_column.unique())
# Out:
# ['classic pop and rock' 'punk' 'folk' 'pop' 'dance and electronica'
#  'metal' 'jazz and blues' 'classical' 'hip-hop' 'soul and reggae']

# %%
pandas_data.describe()
# Out:
#            loudness         tempo  time_signature           key          mode  \
# count  59600.000000  59600.000000    59600.000000  59600.000000  59600.000000
# mean     -11.466464    122.644482        3.509027      5.246913      0.698221
# std        5.443875     35.026345        1.276733      3.578031      0.459034
# min      -54.352000      0.000000        0.000000      0.000000      0.000000
# 25%      -14.082000     97.593750        3.000000      2.000000      0.000000
# 50%      -10.491000    120.008000        4.000000      5.000000      1.000000
# 75%       -7.584000    142.873000        4.000000      9.000000      1.000000
# max        2.865000    260.547000        7.000000     11.000000      1.000000
#
#            duration   avg_timbre1   avg_timbre2   avg_timbre3   avg_timbre4  \
# count  59600.000000  59600.000000  59600.000000  59600.000000  59600.000000
# mean     249.368358     41.271798     -7.839749      8.693922      0.673991
# std      124.893946      6.464746     53.460157     37.083264     16.630815
# min        0.809340      1.749000   -318.656281   -257.525596   -120.723153
# 25%      180.923630     37.804325    -38.164928    -13.297080     -9.371414
# 50%      228.675460     42.188843     -2.521511     10.010756     -0.521686
# 75%      287.790570     45.824781     28.638475     31.275820      9.248637
# max     2873.808530     58.011152    448.373214    305.121388    197.754968
#
#            ...        var_timbre3   var_timbre4   var_timbre5   var_timbre6  \
# count      ...       59600.000000  59600.000000  59600.000000  59600.000000
# mean       ...        2086.250864   1607.670013    917.237656    915.557664
# std        ...        1275.619303   1070.795666    449.432854    560.966191
# min        ...          91.135450     89.873158     50.263681     30.938177
# 25%        ...        1234.942691    932.625215    627.098804    539.826667
# 50%        ...        1809.291704   1362.507241    828.176782    786.076527
# 75%        ...        2610.696799   1968.422690   1100.478252   1137.946415
# max        ...       20131.148234  25470.972456  16049.083490   8278.809040
#
#         var_timbre7   var_timbre8   var_timbre9  var_timbre10  var_timbre11  \
# count  59600.000000  59600.000000  59600.000000  59600.000000  59600.000000
# mean     640.237565    519.352750    418.414959    332.625407    296.605875
# std      322.336675    292.539840    224.209344    160.086746    176.123726
# min       30.922193     30.063717     22.940235     21.861296     20.006805
# 25%      431.101134    335.118547    280.372758    228.582872    183.211753
# 50%      581.836336    456.921498    371.027720    303.594430    256.649101
# 75%      777.363086    624.078399    497.891767    399.912786    361.603655
# max     8044.771043   7192.175853   6195.991985   2707.802218   4780.290858
#
#        var_timbre12
# count  59600.000000
# mean     318.402798
# std      172.836909
# min       21.180689
# 25%      220.061351
# 50%      287.583772
# 75%      373.889954
# max     9599.902501
#
# [8 rows x 30 columns]

# %%
pandas_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59600 entries, 0 to 59599
# Data columns (total 34 columns):
# %genre             59600 non-null object
# artist_name        59600 non-null object
# title              59600 non-null object
# loudness           59600 non-null float64
# tempo              59600 non-null float64
# time_signature     59600 non-null int64
# key                59600 non-null int64
# mode               59600 non-null int64
# duration           59600 non-null float64
# avg_timbre1        59600 non-null float64
# avg_timbre2        59600 non-null float64
# avg_timbre3        59600 non-null float64
# avg_timbre4        59600 non-null float64
# avg_timbre5        59600 non-null float64
# avg_timbre6        59600 non-null float64
# avg_timbre7        59600 non-null float64
# avg_timbre8        59600 non-null float64
# avg_timbre9        59600 non-null float64
# avg_timbre10       59600 non-null float64
# avg_timbre11       59600 non-null float64
# avg_timbre12       59600 non-null float64
# var_timbre1        59600 non-null float64
# var_timbre2        59600 non-null float64
# var_timbre3        59600 non-null float64
# var_timbre4        59600 non-null float64
# var_timbre5        59600 non-null float64
# var_timbre6        59600 non-null float64
# var_timbre7        59600 non-null float64
# var_timbre8        59600 non-null float64
# var_timbre9        59600 non-null float64
# var_timbre10       59600 non-null float64
# var_timbre11       59600 non-null float64
# var_timbre12       59600 non-null float64
# tokenized_title    59600 non-null object
# dtypes: float64(27), int64(3), object(4)
# memory usage: 15.5+ MB

# %%
pandas_data = sklearn.utils.shuffle(pandas_data)

test_df = pandas_data[:int(len(pandas_data)*0.2)]
train_df = pandas_data[int(len(pandas_data)*0.2):]

print(len(train_df))
print(len(test_df))
# Out:
# 47680
# 11920

# %%
red_blue = ['#e6194b', '#0082c8','#bdd600','#911eb4', '#dbbe00', '#3cb44b','#ffe119','#008080', '#f032e6']
palette = sb.color_palette(red_blue)
sb.set_palette(palette)
sb.set_style('white')

fig = plt.figure(figsize=(10,8))
sb.countplot(x="%genre", data=pandas_data, palette=red_blue)

# %%
classical = pandas_data[pandas_data['%genre'] == 'classical']['tempo']
dance = pandas_data[pandas_data['%genre'] == 'dance and electronica']['tempo']
folk = pandas_data[pandas_data['%genre'] == 'folk']['tempo']
hiphop = pandas_data[pandas_data['%genre'] == 'hip-hop']['tempo']
jazz = pandas_data[pandas_data['%genre'] == 'jazz and blues']['tempo']
metal = pandas_data[pandas_data['%genre'] == 'metal']['tempo']
pop = pandas_data[pandas_data['%genre'] == 'pop']['tempo']
poprock = pandas_data[pandas_data['%genre'] == 'classic pop and rock']['tempo']
punk = pandas_data[pandas_data['%genre'] == 'punk']['tempo']
reggae = pandas_data[pandas_data['%genre'] == 'soul and reggae']['tempo']

fig = plt.figure(figsize=(10,10))
plt.title('Tempo by genre')
classical.hist(alpha=0.7, bins = 30, label='classical',histtype='step')
dance.hist(alpha=0.7, bins = 30, label='dance and electronica',histtype='step')
folk.hist(alpha=0.7, bins = 30, label='folk',histtype='step')
hiphop.hist(alpha=0.7, bins = 30, label='hip-hop',histtype='step')
jazz.hist(alpha=1, bins = 30, label='jazz and blues',histtype='step')
metal.hist(alpha=1, bins = 30, label='metal',histtype='step')
pop.hist(alpha=1, bins = 30, label='pop',histtype='step')
poprock.hist(alpha=1, bins = 30, label='classic pop and rock',histtype='step')
punk.hist(alpha=1, bins = 30, label='punk',histtype='step')
reggae.hist(alpha=1, bins = 30, label='soul and reggae',histtype='step')


plt.legend(loc = "upper right")

# %%
fig2 = plt.figure(figsize=(17, 17))

#Duration 
ax1 = fig2.add_subplot(221)
ax1.set_xlabel('Duration')
ax1.set_ylabel('Count')
ax1.set_title('Title')
classical = pandas_data[pandas_data['%genre'] == 'classical']['duration']
dance = pandas_data[pandas_data['%genre'] == 'dance and electronica']['duration']
folk = pandas_data[pandas_data['%genre'] == 'folk']['duration']
hiphop = pandas_data[pandas_data['%genre'] == 'hip-hop']['duration']
jazz = pandas_data[pandas_data['%genre'] == 'jazz and blues']['duration']
metal = pandas_data[pandas_data['%genre'] == 'metal']['duration']
pop = pandas_data[pandas_data['%genre'] == 'pop']['duration']
poprock = pandas_data[pandas_data['%genre'] == 'classic pop and rock']['duration']
punk = pandas_data[pandas_data['%genre'] == 'punk']['duration']
reggae = pandas_data[pandas_data['%genre'] == 'soul and reggae']['duration']
classical.hist(alpha=0.7, bins = 30, label='classical',histtype='step')
dance.hist(alpha=0.7, bins = 30, label='dance and electronica',histtype='step')

hiphop.hist(alpha=0.7, bins = 30, label='hip-hop',histtype='step')
jazz.hist(alpha=1, bins = 30, label='jazz and blues',histtype='step')
metal.hist(alpha=1, bins = 30, label='metal',histtype='step')
pop.hist(alpha=1, bins = 30, label='pop',histtype='step')

punk.hist(alpha=1, bins = 30, label='punk',histtype='step')
reggae.hist(alpha=1, bins = 30, label='soul and reggae',histtype='step')
plt.legend(loc = "upper right")

ax3 = fig2.add_subplot(223)
ax3.set_xlabel('Duration')
ax3.set_ylabel('Count')
ax3.set_title('Title')
folk.hist(alpha=0.7, bins = 30, label='folk',histtype='step')
poprock.hist(alpha=1, bins = 30, label='classic pop and rock',histtype='step')
plt.legend(loc = "upper right")

#Loudness
ax2 = fig2.add_subplot(222)
ax2.set_xlabel('Loudness')
ax2.set_ylabel('Count')
ax2.set_title('Title')

classical = pandas_data[pandas_data['%genre'] == 'classical']['loudness']
dance = pandas_data[pandas_data['%genre'] == 'dance and electronica']['loudness']
folk = pandas_data[pandas_data['%genre'] == 'folk']['loudness']
hiphop = pandas_data[pandas_data['%genre'] == 'hip-hop']['loudness']
jazz = pandas_data[pandas_data['%genre'] == 'jazz and blues']['loudness']
metal = pandas_data[pandas_data['%genre'] == 'metal']['loudness']
pop = pandas_data[pandas_data['%genre'] == 'pop']['loudness']
poprock = pandas_data[pandas_data['%genre'] == 'classic pop and rock']['loudness']
punk = pandas_data[pandas_data['%genre'] == 'punk']['loudness']
reggae = pandas_data[pandas_data['%genre'] == 'soul and reggae']['loudness']

classical.hist(alpha=0.7, bins = 30, label='classical',histtype='step')
dance.hist(alpha=0.7, bins = 30, label='dance and electronica',histtype='step')
hiphop.hist(alpha=0.7, bins = 30, label='hip-hop',histtype='step')
jazz.hist(alpha=1, bins = 30, label='jazz and blues',histtype='step')
metal.hist(alpha=1, bins = 30, label='metal',histtype='step')
pop.hist(alpha=1, bins = 30, label='pop',histtype='step')
punk.hist(alpha=1, bins = 30, label='punk',histtype='step')
reggae.hist(alpha=1, bins = 30, label='soul and reggae',histtype='step')
plt.legend(loc = "upper left")

ax4 = fig2.add_subplot(224)
ax4.set_xlabel('Loudness')
ax4.set_ylabel('Count')
ax4.set_title('Title')
folk.hist(alpha=0.7, bins = 30, label='folk',histtype='step')
poprock.hist(alpha=1, bins = 30, label='classic pop and rock',histtype='step')
plt.legend(loc = "upper left")

# %%
c = DecisionTreeClassifier(min_samples_split=200)

# %%
features = ['loudness', 'tempo', 'time_signature', 'key', 'mode', 'duration', 'avg_timbre1',
           'avg_timbre1','avg_timbre2','avg_timbre3','avg_timbre4','avg_timbre5','avg_timbre6',
           'avg_timbre9','avg_timbre8','avg_timbre9','avg_timbre10','avg_timbre11','avg_timbre12',
           'var_timbre1','var_timbre2','var_timbre3','var_timbre4','var_timbre5','var_timbre6',
           'var_timbre7','var_timbre8','var_timbre9','var_timbre10','var_timbre11','var_timbre12',]

# %%
x_train = train_df[features]
y_train = train_df['%genre']

x_test = test_df[features]
y_test = test_df['%genre']

dt = c.fit(x_train,y_train)
dt
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=200,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
def printTree(tree, features, path):
    f = io.StringIO()
    export_graphviz(tree, out_file=f, feature_names=features)
    pydotplus.graph_from_dot_data(f.getvalue()).write_png(path)
    img = misc.imread(path)
    plt.rcParams['figure.figsize'] = (20,20)
    plt.imshow(img)

printTree(dt, features, 'tree01.png')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.625551 to fit
# c:\users\jakub\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """
# c:\users\jakub\appdata\local\programs\python\python36\lib\site-packages\PIL\Image.py:2509: DecompressionBombWarning: Image size (105182070 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning)

# %%
y_pred = c.predict(x_test)
score = accuracy_score(y_test, y_pred)*100

print(score)
print(f1_score(y_test, y_pred, average=None)*100)
# Out:
# 50.52852348993289
# [60.31828855 56.14973262 36.05797101 48.99342236  0.         33.60655738
#  52.8         0.57471264 42.40740741 23.58235824]
# c:\users\jakub\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
